# %% [markdown]
# # Tugas Pertemuan 2 - Struktur Data Python, NumPy, dan Pandas
#
# **Nama:** Nabil Fakhrezy
# **NIM:** 240401010286
# **Kelas:** IF401
# **Program Studi:** PJJ Informatika
#
# ## Materi
# Analisis dasar dataset Titanic menggunakan Pandas.

# %% [markdown]
# ## 1. Load Dataset Titanic

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
display(df.head())

# %% [markdown]
# ## Q1. Jumlah Baris, Kolom, dan Kolom Dataset

# %%
print("Jumlah baris dan kolom:", df.shape)
print("Kolom yang tersedia:")
print(df.columns.tolist())

# %% [markdown]
# **Jawaban:** Dataset Titanic memiliki 891 baris dan 12 kolom.

# %% [markdown]
# ## Q2. Missing Values

# %%
missing = df.isnull().sum()
missing_percent = (missing / len(df) * 100).round(2)
hasil_missing = pd.DataFrame({"Jumlah Missing": missing, "Persentase (%)": missing_percent})
display(hasil_missing[hasil_missing["Jumlah Missing"] > 0])

# %% [markdown]
# **Jawaban:** Kolom yang memiliki missing values adalah Age, Cabin, dan Embarked.

# %% [markdown]
# ## Q3. Persentase Penumpang Selamat

# %%
persen_selamat = df["Survived"].mean() * 100
print(f"Persentase penumpang yang selamat: {persen_selamat:.2f}%")

# %% [markdown]
# ## Q4. Penumpang Wanita Kelas 1

# %%
wanita_kelas1 = df[(df["Sex"] == "female") & (df["Pclass"] == 1)]
print("Jumlah:", len(wanita_kelas1))
print(f"Rata-rata usia: {wanita_kelas1['Age'].mean():.2f}")

# %% [markdown]
# ## Q5. Tingkat Keselamatan per Kelas dan Gender

# %%
display((df.groupby("Pclass")["Survived"].mean() * 100).round(2))
display((df.groupby("Sex")["Survived"].mean() * 100).round(2))

# %% [markdown]
# ## Kesimpulan
#
# Saya mempelajari cara membaca dataset, memeriksa struktur data, missing values, dan membuat analisis sederhana. Temuan utama adalah tingkat keselamatan berbeda berdasarkan kelas dan gender. Keterbatasannya, beberapa kolom seperti Cabin memiliki banyak missing values.
